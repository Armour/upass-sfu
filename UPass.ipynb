# %%
import requests
import json
from lxml import html, etree

r = requests.Session()
# r.headers.update({'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'})

r1 = r.get('https://upassbc.translink.ca/')
# print(r1.status_code)
# print(r1.cookies)

r2 = r.post('https://upassbc.translink.ca/', data={'PsiId':'sfu'})
# print(r2.status_code)
# print(r2.cookies)
# for history in r2.history:
#     print(history)
#     print(history.url)
tree = html.fromstring(r2.content)
form = tree.find('.//form[@class="signin-form"]')
hiddenFields = form.findall('.//input[@type="hidden"]')
with open('config.json') as config:    
    data = json.load(config)
for hiddenField in hiddenFields:
    data[hiddenField.name] = hiddenField.value
# print(r.cookies)

r3 = r.post('https://cas.sfu.ca' + form.action, data=data)
# print(r3.status_code)
# print(r3.cookies)
# for history in r3.history:
#     print(history)
#     print(history.url)
tree = html.fromstring(r3.content)
form = tree.find('.//form')
fields = form.findall('.//input')
data = {}
for field in fields:
    data[field.name] = field.value

r4 = r.post('https://upassadfs.translink.ca/adfs/ls/', data=data)
# print(r4.status_code)
# print(r4.cookies)
# for history in r4.history:
#     print(history)
#     print(history.url)
tree = html.fromstring(r4.content)
form = tree.find('.//form')
fields = form.findall('.//input')
data = {}
for field in fields:
    data[field.name] = field.value

r5 = r.post('https://upassbc.translink.ca/fs/', data=data)
# print(r5.status_code)
# print(r5.cookies)
# for history in r5.history:
#     print(history)
#     print(history.url)
print(r5.text)
# Out:
# <!DOCTYPE html>
# <!--[if IE]><![endif]-->
# <!--[if lt IE 9]><html lang="en" class="lt-ie9"><![endif]-->
# <!--[if IE 9]><html lang="en" class="lt-ie10"><![endif]-->
# <!--[if (gt IE 9)|!(IE)]><!-->
# <html lang="en">
# <!--<![endif]-->
# <head>
#     <meta charset="utf-8" />
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta http-equiv="Cache-Control" content="no-cache, no-store, must-revalidate, max-age=0">
#     <meta http-equiv="Pragma" content="no-cache">
#     <meta http-equiv="Expires" content="0">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <meta name="format-detection" content="telephone=no">
#
#     <meta name="description" content="Link your Compass Card to your U-Pass BC to load your monthly pass and check your eligibility." />
#     <title>My U-Pass BC</title>
#     <!--[if lt IE 9]><link rel="stylesheet" href="/fs/Content/css/site.legacy.css" /><![endif]-->
#     <!--[if lt IE 9]><link rel="stylesheet" href="/fs/Content/site.addon.legacy.css" /><![endif]-->
#     <noscript>
#         <link href="/fs/Content/css/icons/icons.fallback.css" rel="stylesheet">
#     </noscript>
#     <link href="/fs/Content/sitecss?v=UlgOLU-JQ8XODgeQA6raR5t5BchbuXix6S_SxLK8dEM1" rel="stylesheet"/>
#
#     <link href="/fs/Content/themes/base/css?v=1ipM9g8nmhfMCv_Illt3tP1WApJEd29BoGxoN0D_Zso1" rel="stylesheet"/>
#
#     <script src="/fs/bundles/modernizr?v=jmdBhqkI3eMaPZJduAyIYBj7MpXrGd2ZqmHAOSNeYcg1"></script>
#
#     <script src="/fs/bundles/jquery?v=wBUqTIMTmGl9Hj0haQMeRbd8CoM3UaGnAwp4uDEKfnM1"></script>
#
#     <script src="/fs/bundles/jqueryval?v=WDt8lf51bnC546FJKW5By7_3bCi9X11Mr6ray08RhNs1"></script>
#
#     <script src="/fs/bundles/jqueryui?v=Cw2yi596KkdaXwiCw0hcihY771buayEuXXWppd89Tsk1"></script>
#
#     <script src="/fs/bundles/siterefresh?v=SrobKbj2uagTPFofV_fOWjUkfBF5yKBQFQAdrsuQ1MA1"></script>
#
#     <script src="/fs/bundles/scripts?v=axiLYyL2llzxfWmZdX3lOjLajuGECPwfE27eNpQhyUc1"></script>
#
#     <script src="/fs/bundles/doubletaptogo?v=iGLI5MbUVI9XkRTzFZDfUk0uOyIId_OoCfpc2GkBSVU1"></script>
#
#     <!--[if lt IE 9]><script src="/fs/Content/scripts/html5shiv.min.js"></script><![endif]-->
# </head>
# <body>
#     <div class="header wrapper">
#         <div class="container">
#             <header class="inner">
#                 <a href="/fs/" title="Home"><span class="icon-logo-upass hidden-text"></span></a>
#                 <div class="utility-links">
#
#
# <a href="/fs/Home/Logout?logoutId=0" id="logout-link">Log out</a>
#
#
# <div id="dialogNotificationSetupPromptForm" title="Reminder: Set Up Notifications">
# <form action="/fs/Home/LogoutFromPrompt" id="LogoutFromPromptForm" method="post">    <P>Receive notifications for:
#         <UL>
#             <LI>Monthly reminders to request your U-Pass BC</LI>
#             <LI>Confirmations when your U-Pass BC has been processed</LI>
#             <LI>Important messages relating to your account</LI>
#         </UL>
#     </P>
# <input id="DoNotShowMessageAgain" name="DoNotShowMessageAgain" type="checkbox" value="true" /><input name="DoNotShowMessageAgain" type="hidden" value="false" /><label for="DoNotShowMessageAgain" style="display:inline"> Do not show this message again.</label><input id="dialogNotificationSetupPromptFormAction" name="dialogNotificationSetupPromptFormAction" type="hidden" value="" /></form></div>
#
# <script type="text/javascript">
#
#     (function($) {
#         'use strict';
#         var dialog = $("#dialogNotificationSetupPromptForm").dialog({
#             autoOpen: false,
#             height: "auto",
#             width: "auto",
#             modal: true,
#             open: function (event, ui) { $(".ui-dialog-titlebar-close", ui.dialog | ui).hide(); },
#             closeOnEscape: true,
#             buttons:
#             {
#                 'Do': {
#                     text: 'Set Up Notifications',
#                     id: 'SetupNotificationsButton',
#                     click: function() {
#                         $('#dialogNotificationSetupPromptFormAction').val("SetupNotification");
#                         $('#LogoutFromPromptForm').submit();
#                     }
#                 }/*,
#                 'Cancel': {
#                     text: 'No thanks',
#                     id: 'LogOutButton',
#                     click: function() {
#                         $('#dialogNotificationSetupPromptFormAction').val("Logout");
#                         $('#LogoutFromPromptForm').submit();
#                     }
#                 }*/
#             }
#         });
#
#         dialog.parent().find('.ui-dialog-buttonset').append('<a href="javascript:void(0);" id="LogOutLink">No Thanks</a>');
#         $('#LogOutLink').click(function () {
#             $('#dialogNotificationSetupPromptFormAction').val("Logout");
#             $('#LogoutFromPromptForm').submit();
#         });
#
#         $('#logout-link').on('click', function (e) {
#             e.preventDefault();
#             $.ajax({
#                 url: '/fs/Home/PromptForNotificationRegistrationOnLogout',
#                 type: 'GET',
#                 dataType: 'json',
#                 cache: false
#             }).done(function (data) {
#                 if (data == true) {
#                     dialog.dialog('open');
#                 } else {
#                     window.location = '/fs/Home/Logout?logoutId=0';
#                 }
#             }).fail(function () {
#                 window.location = '/fs/Home/Logout?logoutId=0';
#             });
#         });
#
#     })(jQuery);
# </script>
#
#
#                 </div>
#                 <nav class="navigation">
#                     <button class="nav-toggle icon-burger-off" aria-hidden="true" tabindex="-1"></button>
#                     <ul class="nav-menu nav-menu-closed">
#                             <li><a class="bold" href="/fs/">My U-Pass BC <span class="triangle"></span></a>
#                                 <ul>
#                                     <li><a class="navItem" href="/fs/CompassCard/Unlink?reason=None">Unlink Compass Card</a></li>
#                                     <li><a href="/fs/Eligibility">Eligibility</a></li>
#                                     <li><a href="/fs/Notifications">Notifications</a></li>
#
#                                 </ul>
#                             </li>
#
#                         <li><a class="bold" href="/fs/Help/FAQ">Help <span class="triangle"></span></a>
#                             <ul>
#                                 <li><a href="/fs/Help/Guide">Getting Started Guide</a></li>
#                                 <li><a href="/fs/Help/ContactUs">Contact Us</a></li>
#                             </ul>
#                         </li>
#                     </ul>
#                 </nav>
#
#             </header>
#         </div>
#     </div>
#
#
#
#
#     <div class="alert notify wrapper">
#         <div class="container">
#             <div class="inner">
#                 <div class="alert-box" id="alertBox" role="alert">
#                     <div class="alert-text icon-alert-none">Your U-Pass BC is ready to be requested.</div>
#                 </div>
#             </div>
#         </div>
#     </div>
#
# <div class="content wrapper" id="home-page">
#     <div class="container">
#         <div class="inner">
#
#             <h1>My U-Pass BC</h1>
#
#     <div class="icon-card-info">0164  0496  5267  9910  0166</div>
#                 <div class="group">
#
#                     <div class="column width-half">
#                         <div class="block filled">
#                             <div class="inner">
#                                 <h2 class="underline">Request your U-Pass BC</h2>
#
# <div class="intro-block icon-scan-card">
#     <div>To request your U-Pass BC select the month and click "Request".</div>
#     <br />
#     <div>During busy times it may take up to 24 hours for your U-Pass BC to load to your Compass Card.</div>
# </div>
#
# <form action="/fs/Eligibility/Request" id="form-request" method="post"><input id="AccountStatus" name="AccountStatus" type="hidden" value="Active" /><input data-val="true" data-val-required="The AllowBenefitRequest field is required." id="AllowBenefitRequest" name="AllowBenefitRequest" type="hidden" value="True" /><input id="Card_CardNumber" name="Card.CardNumber" type="hidden" value="01640496526799100166" /><input data-val="true" data-val-number="The field CardStatus must be a number." data-val-required="The CardStatus field is required." id="Card_CardStatus" name="Card.CardStatus" type="hidden" value="0" /><input data-val="true" data-val-number="The field StudentCardStatus must be a number." data-val-required="The StudentCardStatus field is required." id="Card_StudentCardStatus" name="Card.StudentCardStatus" type="hidden" value="3" />
#
# <div class="tooltips"></div>
#
# <table>
#     <thead>
#     <tr>
#         <th>Month</th>
#         <th><span class="icon-tooltip" aria-describedby="eligible" aria-role="button" data-type="eligible" data-message="&lt;div&gt;Eligibility for the U-Pass BC program is provided by your post-secondary institution. Before you can request your U-Pass BC, your eligibility information must be present.&lt;/div&gt;
# &lt;br/&gt;
# &lt;div&gt;If your status displays an &#39;N/A&#39;, our system hasn&#39;t received your eligibility confirmation yet. At the start of a semester or program, it may take 24 hours or longer for your eligibility to be updated. If you have questions about your eligibility, please &lt;a href=&quot;/fs/Help/ContactUs&quot;&gt;contact your school&lt;/a&gt; directly.&lt;/div&gt;" href="#">Eligible</span></th>
#         <th><span class="icon-tooltip" aria-describedby="request" aria-role="button" data-type="request" data-message="
# &lt;div&gt;&lt;b&gt;Able to request as of 16&lt;sup&gt;th&lt;/sup&gt;&lt;/b&gt;: You can request your U-Pass BC on or after the 16&lt;sup&gt;th&lt;/sup&gt; of this month.&lt;/div&gt;
# &lt;div&gt;&lt;b&gt;Requested&lt;/b&gt;: We are processing your request.&lt;/div&gt;
# &lt;div&gt;&lt;b&gt;Processed&lt;/b&gt;: Your U-Pass BC has been processed and will be loaded on to your Compass Card. Please allow up to 24 hours for your U-Pass BC to load and be ready for use.&lt;/div&gt;
# &lt;div&gt;&lt;b&gt;Unavailable&lt;/b&gt;: A U-Pass BC is not available to load for the corresponding month, or your eligibility has not yet been received.&lt;/div&gt;
# " href="#">Request U-Pass BC</span></th>
#     </tr>
#     </thead>
#     <tbody>
# <input data-val="true" data-val-date="The field CurrentDate must be a date." data-val-required="The CurrentDate field is required." id="CurrentDate" name="CurrentDate" type="hidden" value="10/24/2017 8:55:23 AM" /><input data-val="true" data-val-required="The HasCcsnInSession field is required." id="HasCcsnInSession" name="HasCcsnInSession" type="hidden" value="False" />
#         <tr>
#             <td>October 2017</td>
#             <td>Yes</td>
# <input id="Eligibility_0__Eligible" name="Eligibility[0].Eligible" type="hidden" value="True" /><input data-val="true" data-val-required="The Loaded field is required." id="Eligibility_0__Loaded" name="Eligibility[0].Loaded" type="hidden" value="True" /><input data-val="true" data-val-number="The field Month must be a number." data-val-required="The Month field is required." id="Eligibility_0__Month" name="Eligibility[0].Month" type="hidden" value="10" /><input data-val="true" data-val-number="The field RequestBenefitOption must be a number." data-val-required="The RequestBenefitOption field is required." id="Eligibility_0__RequestBenefitOption" name="Eligibility[0].RequestBenefitOption" type="hidden" value="3" /><input data-val="true" data-val-required="The Requested field is required." id="Eligibility_0__Requested" name="Eligibility[0].Requested" type="hidden" value="True" /><input data-val="true" data-val-required="The Source field is required." id="Eligibility_0__Source" name="Eligibility[0].Source" type="hidden" value="Psi" /><input data-val="true" data-val-number="The field Year must be a number." data-val-required="The Year field is required." id="Eligibility_0__Year" name="Eligibility[0].Year" type="hidden" value="2017" />            <td>
#                     <div class="status">Processed</div>
#             </td>
#         </tr>
#         <tr>
#             <td>November 2017</td>
#             <td>Yes</td>
# <input id="Eligibility_1__Eligible" name="Eligibility[1].Eligible" type="hidden" value="True" /><input data-val="true" data-val-required="The Loaded field is required." id="Eligibility_1__Loaded" name="Eligibility[1].Loaded" type="hidden" value="False" /><input data-val="true" data-val-number="The field Month must be a number." data-val-required="The Month field is required." id="Eligibility_1__Month" name="Eligibility[1].Month" type="hidden" value="11" /><input data-val="true" data-val-number="The field RequestBenefitOption must be a number." data-val-required="The RequestBenefitOption field is required." id="Eligibility_1__RequestBenefitOption" name="Eligibility[1].RequestBenefitOption" type="hidden" value="4" /><input data-val="true" data-val-required="The Requested field is required." id="Eligibility_1__Requested" name="Eligibility[1].Requested" type="hidden" value="False" /><input data-val="true" data-val-required="The Source field is required." id="Eligibility_1__Source" name="Eligibility[1].Source" type="hidden" value="Psi" /><input data-val="true" data-val-number="The field Year must be a number." data-val-required="The Year field is required." id="Eligibility_1__Year" name="Eligibility[1].Year" type="hidden" value="2017" />            <td>
#                     <div>
#                         <input data-val="true" data-val-required="The Selected field is required." id="chk_1" name="Eligibility[1].Selected" type="checkbox" value="true" /><input name="Eligibility[1].Selected" type="hidden" value="false" />
#                         <label for="chk_1" class="element-invisible">&nbsp;</label>
#                     </div>
#             </td>
#         </tr>
#     </tbody>
# </table>
#
# <span id="lblError" style="position:absolute;bottom:0px;color:transparent;"></span>
#
#             <div class="form-element">
#                 <div class="elm-label"><label>When travelling with a Compass Card loaded with a U-Pass BC, you must carry your valid student ID as proof of payment. </label>
#                 </div>
#                 <div class="elm-btn"><input type="submit" value="Request" id="requestButton" name="requestButton"/></div>
#             </div>
# </form>
#                             </div>
#                         </div>
#                     </div>
#
#
#                     <div class="column width-half">
#                         <div class="block filled">
#                             <div class="block filled" id="divNotificationsBox" data-url="/fs/Home/GetNotifications">
#                                 <div class="inner">
#     <h2 class="underline">Notifications</h2>
#     <img src="/fs/Content/images/ajax-loader.gif" class="center" alt="" />
# </div>
#
#                             </div>
#                         </div>
#                         <div class="block filled">
#                             <div class="inner">
#
# <script>
#     $(document).ready(function () {
#         $('[id^=mcSubject_]').on('click', function () {
#             var animationIsOff = $.fx.off;
#             var id = this.id.substr(10, 36);
#             $.fx.off = false;
#             if ($(this).children('span').hasClass('icon-collapse') && !$(this).hasClass('read')) {
#                 $(this).addClass('read');
#                 $.ajax({
#                     url: '/fs/Notifications/SetMessageStatusToRead',
#                     type: 'GET',
#                     dataType: 'json',
#                     cache: false,
#                     data: { studentNotificationId: id },
#                 }).done(function (data) {
#                 }).fail(function (request, status, error) {
#                     LogError(id, 'read', request.status);
#                 });
#             }
#             $.fx.off = animationIsOff;
#         });
#     })
# </script>
#
# <h2 class="underline" id="MyMessagesBlock">My messages</h2>
#         <div class="block filled" id="NotificationMessages">
#             <div class="inner">
#                 <div class="expand-group">
#                         <a id="mcSubject_308cab1c-2500-4de6-abfe-3d87a8a0424d" class="expand-control"><h3>Your U-Pass BC is ready!</h3><span></span></a>
#                         <div id="mcBody_308cab1c-2500-4de6-abfe-3d87a8a0424d" class="expand-content" aria-live="polite" role="region">
#                             <p>Your October, 2017 U-Pass BC has been processed, and will be loaded to your Compass Card before the start of the month.</p>
#
#                             <p style="text-align: right"><a href="javascript:void(0)" onclick="DeleteMessage('308cab1c-2500-4de6-abfe-3d87a8a0424d')">Delete message</a></p>
#                         </div>
#                         <a id="mcSubject_20d83561-190d-4042-abc4-e3132a25d5d7" class="expand-control"><h3>Your U-Pass BC is ready!</h3><span></span></a>
#                         <div id="mcBody_20d83561-190d-4042-abc4-e3132a25d5d7" class="expand-content" aria-live="polite" role="region">
#                             <p>Your September, 2017 U-Pass BC has been processed, and will be loaded to your Compass Card before the start of the month.</p>
#
#                             <p style="text-align: right"><a href="javascript:void(0)" onclick="DeleteMessage('20d83561-190d-4042-abc4-e3132a25d5d7')">Delete message</a></p>
#                         </div>
#                         <a id="mcSubject_7075418a-69c0-47cc-8188-bae84bc6a6ab" class="expand-control"><h3>Your U-Pass BC is ready!</h3><span></span></a>
#                         <div id="mcBody_7075418a-69c0-47cc-8188-bae84bc6a6ab" class="expand-content" aria-live="polite" role="region">
#                             <p>Your August, 2017 U-Pass BC has been processed, and will be loaded to your Compass Card before the start of the month.</p>
#
#                             <p style="text-align: right"><a href="javascript:void(0)" onclick="DeleteMessage('7075418a-69c0-47cc-8188-bae84bc6a6ab')">Delete message</a></p>
#                         </div>
#                         <a id="mcSubject_52c27b47-61fd-4e02-98fe-82cff1f67366" class="expand-control"><h3>Your U-Pass BC is ready!</h3><span></span></a>
#                         <div id="mcBody_52c27b47-61fd-4e02-98fe-82cff1f67366" class="expand-content" aria-live="polite" role="region">
#                             <p>Your July, 2017 U-Pass BC has been processed, and will be loaded to your Compass Card before the start of the month.</p>
#
#                             <p style="text-align: right"><a href="javascript:void(0)" onclick="DeleteMessage('52c27b47-61fd-4e02-98fe-82cff1f67366')">Delete message</a></p>
#                         </div>
#                         <a id="mcSubject_edc66cd7-bdbb-49c0-81f9-c84121e8f559" class="expand-control"><h3>Your U-Pass BC is ready!</h3><span></span></a>
#                         <div id="mcBody_edc66cd7-bdbb-49c0-81f9-c84121e8f559" class="expand-content" aria-live="polite" role="region">
#                             <p>Your June, 2017 U-Pass BC has been processed, and will be loaded to your Compass Card before the start of the month.</p>
#
#                             <p style="text-align: right"><a href="javascript:void(0)" onclick="DeleteMessage('edc66cd7-bdbb-49c0-81f9-c84121e8f559')">Delete message</a></p>
#                         </div>
#                         <a id="mcSubject_57d1f870-4f83-4e58-b4fd-d25372082bcf" class="expand-control"><h3>Your U-Pass BC is ready!</h3><span></span></a>
#                         <div id="mcBody_57d1f870-4f83-4e58-b4fd-d25372082bcf" class="expand-content" aria-live="polite" role="region">
#                             <p>Your May, 2017 U-Pass BC has been processed, and will be loaded to your Compass Card before the start of the month.</p>
#
#                             <p style="text-align: right"><a href="javascript:void(0)" onclick="DeleteMessage('57d1f870-4f83-4e58-b4fd-d25372082bcf')">Delete message</a></p>
#                         </div>
#                         <a id="mcSubject_b67294ec-3110-4798-b9ef-76c73017bcac" class="expand-control"><h3>Your U-Pass BC is ready!</h3><span></span></a>
#                         <div id="mcBody_b67294ec-3110-4798-b9ef-76c73017bcac" class="expand-content" aria-live="polite" role="region">
#                             <p>Your April, 2017 U-Pass BC has been processed, and will be loaded to your Compass Card before the start of the month.</p>
#
#                             <p style="text-align: right"><a href="javascript:void(0)" onclick="DeleteMessage('b67294ec-3110-4798-b9ef-76c73017bcac')">Delete message</a></p>
#                         </div>
#                         <a id="mcSubject_9a2a4f63-27b6-4037-b20d-593a34b9ec67" class="expand-control"><h3>Your U-Pass BC is ready!</h3><span></span></a>
#                         <div id="mcBody_9a2a4f63-27b6-4037-b20d-593a34b9ec67" class="expand-content" aria-live="polite" role="region">
#                             <p>Your March, 2017 U-Pass BC has been processed, and will be loaded to your Compass Card.</p>
# <p>Please note that during busy times it may take up to 24 hours for your U-Pass BC to be processed and to reach all card readers.</p>
#
#                             <p style="text-align: right"><a href="javascript:void(0)" onclick="DeleteMessage('9a2a4f63-27b6-4037-b20d-593a34b9ec67')">Delete message</a></p>
#                         </div>
#                         <a id="mcSubject_d4ad214a-79c2-423e-89bd-8297087de4b3" class="expand-control"><h3>Your U-Pass BC is ready!</h3><span></span></a>
#                         <div id="mcBody_d4ad214a-79c2-423e-89bd-8297087de4b3" class="expand-content" aria-live="polite" role="region">
#                             <p>Your February, 2017 U-Pass BC has been processed, and will be loaded to your Compass Card.</p>
# <p>Please note that during busy times it may take up to 24 hours for your U-Pass BC to be processed and to reach all card readers.</p>
#
#                             <p style="text-align: right"><a href="javascript:void(0)" onclick="DeleteMessage('d4ad214a-79c2-423e-89bd-8297087de4b3')">Delete message</a></p>
#                         </div>
#                         <a id="mcSubject_322903e6-d8d6-4e5d-bbfe-2602ca19f9d4" class="expand-control"><h3>Your U-Pass BC is ready!</h3><span></span></a>
#                         <div id="mcBody_322903e6-d8d6-4e5d-bbfe-2602ca19f9d4" class="expand-content" aria-live="polite" role="region">
#                             <p>Your January, 2017 U-Pass BC has been processed, and will be loaded to your Compass Card before the start of the month.</p>
#
#                             <p style="text-align: right"><a href="javascript:void(0)" onclick="DeleteMessage('322903e6-d8d6-4e5d-bbfe-2602ca19f9d4')">Delete message</a></p>
#                         </div>
#                         <a id="mcSubject_bd3efc12-8265-42fc-b5ff-a3a2ed353a22" class="expand-control"><h3>Your U-Pass BC is ready!</h3><span></span></a>
#                         <div id="mcBody_bd3efc12-8265-42fc-b5ff-a3a2ed353a22" class="expand-content" aria-live="polite" role="region">
#                             <p>Your December, 2016 U-Pass BC has been processed, and will be loaded to your Compass Card before the start of the month.</p>
#
#                             <p style="text-align: right"><a href="javascript:void(0)" onclick="DeleteMessage('bd3efc12-8265-42fc-b5ff-a3a2ed353a22')">Delete message</a></p>
#                         </div>
#                         <a id="mcSubject_16975100-a5ba-468f-8bd8-7a1867f2c24d" class="expand-control"><h3>Your U-Pass BC is ready!</h3><span></span></a>
#                         <div id="mcBody_16975100-a5ba-468f-8bd8-7a1867f2c24d" class="expand-content" aria-live="polite" role="region">
#                             <p>Your November, 2016 U-Pass BC has been processed, and will be loaded to your Compass Card before the start of the month.</p>
#
#                             <p style="text-align: right"><a href="javascript:void(0)" onclick="DeleteMessage('16975100-a5ba-468f-8bd8-7a1867f2c24d')">Delete message</a></p>
#                         </div>
#                         <a id="mcSubject_7f9ddf25-8a3e-4e56-83e0-4e12c334a635" class="expand-control"><h3>Your U-Pass BC is ready!</h3><span></span></a>
#                         <div id="mcBody_7f9ddf25-8a3e-4e56-83e0-4e12c334a635" class="expand-content" aria-live="polite" role="region">
#                             <p>Your October, 2016 U-Pass BC has been processed, and will be loaded to your Compass Card.</p>
# <p>Please note that during busy times it may take up to 24 hours for your U-Pass BC to be processed and to reach all card readers.</p>
#
#                             <p style="text-align: right"><a href="javascript:void(0)" onclick="DeleteMessage('7f9ddf25-8a3e-4e56-83e0-4e12c334a635')">Delete message</a></p>
#                         </div>
#                         <a id="mcSubject_274826d2-6603-4524-a4a0-854a61b2ce3c" class="expand-control"><h3>Your U-Pass BC is ready!</h3><span></span></a>
#                         <div id="mcBody_274826d2-6603-4524-a4a0-854a61b2ce3c" class="expand-content" aria-live="polite" role="region">
#                             <p>Your September, 2016 U-Pass BC has been processed, and will be loaded to your Compass Card.</p>
# <p>Please note that during busy times it may take up to 24 hours for your U-Pass BC to be processed and to reach all card readers.</p>
#
#                             <p style="text-align: right"><a href="javascript:void(0)" onclick="DeleteMessage('274826d2-6603-4524-a4a0-854a61b2ce3c')">Delete message</a></p>
#                         </div>
#                         <a id="mcSubject_f247bf39-111d-4c4b-8eac-0d13930249de" class="expand-control"><h3>Your U-Pass BC is ready!</h3><span></span></a>
#                         <div id="mcBody_f247bf39-111d-4c4b-8eac-0d13930249de" class="expand-content" aria-live="polite" role="region">
#                             <p>Your August, 2016 U-Pass BC has been processed, and will be loaded to your Compass Card.</p>
# <p>Please note that during busy times it may take up to 24 hours for your U-Pass BC to be processed and to reach all card readers.</p>
#
#                             <p style="text-align: right"><a href="javascript:void(0)" onclick="DeleteMessage('f247bf39-111d-4c4b-8eac-0d13930249de')">Delete message</a></p>
#                         </div>
#                         <a id="mcSubject_21ab9e00-499c-4d58-83c8-13f848e6ed0c" class="expand-control"><h3>Your U-Pass BC is ready!</h3><span></span></a>
#                         <div id="mcBody_21ab9e00-499c-4d58-83c8-13f848e6ed0c" class="expand-content" aria-live="polite" role="region">
#                             <p>Your July, 2016 U-Pass BC has been processed, and will be loaded to your Compass Card.</p>
# <p>Please note that during busy times it may take up to 24 hours for your U-Pass BC to be processed and to reach all card readers.</p>
#
#                             <p style="text-align: right"><a href="javascript:void(0)" onclick="DeleteMessage('21ab9e00-499c-4d58-83c8-13f848e6ed0c')">Delete message</a></p>
#                         </div>
#                         <a id="mcSubject_d63cc3cb-a5ff-48d0-8560-42ef940c15ee" class="expand-control"><h3>Your U-Pass BC is ready!</h3><span></span></a>
#                         <div id="mcBody_d63cc3cb-a5ff-48d0-8560-42ef940c15ee" class="expand-content" aria-live="polite" role="region">
#                             <p>Your June, 2016 U-Pass BC has been processed, and will be loaded to your Compass Card before the start of the month.</p>
#
#                             <p style="text-align: right"><a href="javascript:void(0)" onclick="DeleteMessage('d63cc3cb-a5ff-48d0-8560-42ef940c15ee')">Delete message</a></p>
#                         </div>
#                         <a id="mcSubject_9cde9997-8e19-4286-8829-c7713373520a" class="expand-control"><h3>Your U-Pass BC is ready!</h3><span></span></a>
#                         <div id="mcBody_9cde9997-8e19-4286-8829-c7713373520a" class="expand-content" aria-live="polite" role="region">
#                             <p>Your May, 2016 U-Pass BC has been processed, and will be loaded to your Compass Card before the start of the month.</p>
#
#                             <p style="text-align: right"><a href="javascript:void(0)" onclick="DeleteMessage('9cde9997-8e19-4286-8829-c7713373520a')">Delete message</a></p>
#                         </div>
#                         <a id="mcSubject_8ca4032d-dc42-4540-bc79-5434ffe1fbe8" class="expand-control"><h3>Your U-Pass BC is ready!</h3><span></span></a>
#                         <div id="mcBody_8ca4032d-dc42-4540-bc79-5434ffe1fbe8" class="expand-content" aria-live="polite" role="region">
#                             <p>Your April, 2016 U-Pass BC has been processed, and will be loaded to your Compass Card before the start of the month.</p>
#
#                             <p style="text-align: right"><a href="javascript:void(0)" onclick="DeleteMessage('8ca4032d-dc42-4540-bc79-5434ffe1fbe8')">Delete message</a></p>
#                         </div>
#                         <a id="mcSubject_f6ac15bd-dc8d-49dd-9afd-15bdfdd25805" class="expand-control"><h3>Your U-Pass BC is ready!</h3><span></span></a>
#                         <div id="mcBody_f6ac15bd-dc8d-49dd-9afd-15bdfdd25805" class="expand-content" aria-live="polite" role="region">
#                             <p>Your March, 2016 U-Pass BC has been processed, and will be loaded to your Compass Card.</p>
# <p>Please note that during busy times it may take up to 24 hours for your U-Pass BC to be processed and to reach all card readers.</p>
#
#                             <p style="text-align: right"><a href="javascript:void(0)" onclick="DeleteMessage('f6ac15bd-dc8d-49dd-9afd-15bdfdd25805')">Delete message</a></p>
#                         </div>
#                         <a id="mcSubject_f3f358cb-10ee-4b19-85aa-519843ad9c00" class="expand-control read"><h3>Your U-Pass BC is ready!</h3><span></span></a>
#                         <div id="mcBody_f3f358cb-10ee-4b19-85aa-519843ad9c00" class="expand-content" aria-live="polite" role="region">
#                             <p>Your February, 2016 U-Pass BC has been processed, and will be loaded to your Compass Card before the start of the month.</p>
#
#                             <p style="text-align: right"><a href="javascript:void(0)" onclick="DeleteMessage('f3f358cb-10ee-4b19-85aa-519843ad9c00')">Delete message</a></p>
#                         </div>
#                         <a id="mcSubject_fe851cd4-6dce-40c2-9504-a7785e173365" class="expand-control read"><h3>Your U-Pass BC is ready!</h3><span></span></a>
#                         <div id="mcBody_fe851cd4-6dce-40c2-9504-a7785e173365" class="expand-content" aria-live="polite" role="region">
#                             <p>Your January, 2016 U-Pass BC has been processed, and will be loaded to your Compass Card before the start of the month.</p>
#
#                             <p style="text-align: right"><a href="javascript:void(0)" onclick="DeleteMessage('fe851cd4-6dce-40c2-9504-a7785e173365')">Delete message</a></p>
#                         </div>
#                         <a id="mcSubject_c76c28cd-ce9f-4a49-9f96-1aa21de35442" class="expand-control"><h3>Your U-Pass BC is ready!</h3><span></span></a>
#                         <div id="mcBody_c76c28cd-ce9f-4a49-9f96-1aa21de35442" class="expand-content" aria-live="polite" role="region">
#                             <p>Your December, 2015 U-Pass BC has been processed, and will be loaded to your Compass Card before the start of the month.</p>
#
#                             <p style="text-align: right"><a href="javascript:void(0)" onclick="DeleteMessage('c76c28cd-ce9f-4a49-9f96-1aa21de35442')">Delete message</a></p>
#                         </div>
#                         <a id="mcSubject_6d257024-fee3-46f8-90e1-5a2d5b6c0601" class="expand-control"><h3>Your U-Pass BC is ready!</h3><span></span></a>
#                         <div id="mcBody_6d257024-fee3-46f8-90e1-5a2d5b6c0601" class="expand-content" aria-live="polite" role="region">
#                             <p>Your November, 2015 U-Pass BC has been processed, and will be loaded to your Compass Card.</p>
# <p>Please note that during busy times it may take up to 24 hours for your U-Pass BC to be processed and to reach all card readers.</p>
#
#                             <p style="text-align: right"><a href="javascript:void(0)" onclick="DeleteMessage('6d257024-fee3-46f8-90e1-5a2d5b6c0601')">Delete message</a></p>
#                         </div>
#                         <a id="mcSubject_b93d772d-4361-420d-a41e-e404e88750be" class="expand-control"><h3>Your U-Pass BC is ready!</h3><span></span></a>
#                         <div id="mcBody_b93d772d-4361-420d-a41e-e404e88750be" class="expand-content" aria-live="polite" role="region">
#                             <p>Your October, 2015 U-Pass BC has been processed, and will be loaded to your Compass Card.</p>
# <p>Please note that during busy times it may take up to 24 hours for your U-Pass BC to be processed and to reach all card readers.</p>
#
#                             <p style="text-align: right"><a href="javascript:void(0)" onclick="DeleteMessage('b93d772d-4361-420d-a41e-e404e88750be')">Delete message</a></p>
#                         </div>
#                         <a id="mcSubject_da667998-7470-465f-b2e1-480d6408a83c" class="expand-control read"><h3>Your U-Pass BC is ready!</h3><span></span></a>
#                         <div id="mcBody_da667998-7470-465f-b2e1-480d6408a83c" class="expand-content" aria-live="polite" role="region">
#                             <p>Your September, 2015 U-Pass BC has been processed, and will be loaded to your Compass Card.</p>
# <p>Please note that during busy times it may take up to 24 hours for your U-Pass BC to be processed and to reach all card readers.</p>
#
#                             <p style="text-align: right"><a href="javascript:void(0)" onclick="DeleteMessage('da667998-7470-465f-b2e1-480d6408a83c')">Delete message</a></p>
#                         </div>
#                 </div>
#             </div>
#         </div>
#
#
# <script type="text/javascript">
#     function DeleteMessage(studentNotificationId) {
#         $.ajax({
#             url: '/fs/Notifications/DeleteMessage',
#             type: 'GET',
#             dataType: 'json',
#             cache: false,
#             data: { studentNotificationId: studentNotificationId },
#         }).done(function (data) {
#         }).fail(function (request, status, error) {
#             LogError(studentNotificationId, 'delete', request.status);
#         });
#         $("#mcSubject_" + studentNotificationId).remove();
#         $("#mcBody_" + studentNotificationId).remove();
#
#
#         if ($('[id^=mcSubject_]').length == 0) {
#             $("#NotificationMessages").remove();
#             $("#MyMessagesBlock").after('<div class="intro-block">There are currently no messages to display.</div>');
#         }
#     }
#
#     function LogError(studentNotificationId, logAction, errorMessage) {
#         $.ajax({
#             url: '/fs/Notifications/LogNotificationMessage',
#             type: 'GET',
#             dataType: 'json',
#             cache: false,
#             data: { studentNotificationId: studentNotificationId, logAction: logAction, errorMessage: errorMessage },
#         }).done(function (data) {
#         }).fail(function (xhr, status, error) {
#         });
#     }
#
# </script>
#
#                             </div>
#                         </div>
#                         <div class="block filled" id="divAccountHistory" data-url="/fs/Home/AccountHistory">
#                         </div>
#                     </div>
#                 </div>
#
#         </div>
#     </div>
# </div>
#
#
#     <div class="footer wrapper">
#         <div class="container">
#             <footer class="inner">
#                 <nav class="group">
#                     <div class="block width-full" id="footer-nav">
#                         <div class="inner" style="padding-bottom: 0px;">
#                             <ul>
#                                 <li><a href="http://compasscard.ca/" target="_blank">CompassCard.ca</a></li>
#                                 <li><a href="/fs/Help/ContactUs">Contact Us</a></li>
#                                 <li><a href="http://www.translink.ca/en/Site-Info/Privacy.aspx" target="_blank">Privacy Policy</a></li>
#                                 <li><a href="https://www.compasscard.ca/TermsAndConditions" target="_blank">Compass Terms &amp; Conditions</a></li>
#                                 <li><a href="http://www.translink.ca/en/Site-Info/Terms-and-conditions.aspx" target="_blank">Website Terms &amp; Conditions</a></li>
#                             </ul>
#                             <p class="copyright">&copy; 2017 TransLink</p>
#                         </div>
#                     </div>
#                     <div class="block width-full float-right" id="footer-logos">
#                         <div class="inner" style="padding-top: 0px;">
#                             <div>
#                                 <a class="icon-logo-compass hidden-text" href="http://compasscard.ca" target="_blank">Compass</a>
#                             </div>
#                             <div>
#                                 <a class="icon-logo-translink hidden-text" href="http://translink.ca" target="_blank">TransLink</a>
#                             </div>
#                         </div>
#                     </div>
#                 </nav>
#             </footer>
#         </div>
#     </div>
#
# </body>
# </html>
